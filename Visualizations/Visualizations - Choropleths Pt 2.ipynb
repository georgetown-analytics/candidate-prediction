# %% [markdown]
# # Visualizations
#
# This notebooks walks through the process for generating choropleths of the United States, to geographically visualize campaign finance information.

# %% [markdown]
# ## Getting the Data
#
# For these visualizations, we want to sets of data: state of candidate running for election, and donation amount; and then state of the donor, and donation amount.
#
# In order to end up with these two tables, we first need to pull the appropriate data from the database. Then we can drop the fields we will not need, to lessen the size of the data.

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import pandas as pd

# %%
#Define connection. 
#engine=create_engine('postgresql://username:password@host:port/databasename)
engine=create_engine('postgresql://')

#review table names
table_names=engine.table_names()
print(table_names)

# %%
df=pd.read_sql_query('SELECT * from individual_contribution_join_abbreviated', engine)

# %%
df.head()

# %%
df = df.drop("cmte_id", axis = 1)
df = df.drop("amndt_ind", axis = 1)
df = df.drop("rpt_tp", axis = 1)
df = df.drop("result", axis = 1)
df = df.drop("cand_pty_affliation", axis = 1)
df = df.drop("transaction_pgi", axis = 1)
df = df.drop("entity_tp", axis = 1)
df = df.drop("name", axis = 1)
df = df.drop("sub_id", axis = 1)

df.head()

# %%
df.to_csv('fecindividual.csv', sep = ",", index = False)

# %% [markdown]
# ## Cleaning the Data
#
# To get the data properly formatted, we will need substantial cleaning and wrangling of the data:
# -	Filter to only 2014 campaign cycle donations
# -	Identify the state of the candidate (based on the cand_id)
# -	Sum all the donations together that are associated with the same state.

# %%
df = pd.read_csv('fecindividual.csv')

# %%
df.head()
# Out:
#      cand_id state  transaction_dt  transaction_amt
# 0  H4PA13124    PA       4132011.0            250.0
# 1  H4PA13124    NY       6302011.0            250.0
# 2  H4PA13124    NY       6302011.0            250.0
# 3  H4PA13124    PA       6242011.0            250.0
# 4  H4PA13124    PA       6242011.0            250.0

# %%
df['transaction_amt'] = df['transaction_amt'].astype('int')
df['cand_id'] = df['cand_id'].astype('str')
df['state'] = df['state'].astype('str')
df['transaction_dt'] = df['transaction_dt'].astype('str')

# %%
df['transaction_dt'] = df['transaction_dt'].str[3:7]
df.head()
# Out:
#      cand_id state transaction_dt  transaction_amt
# 0  H4PA13124    PA           2011              250
# 1  H4PA13124    NY           2011              250
# 2  H4PA13124    NY           2011              250
# 3  H4PA13124    PA           2011              250
# 4  H4PA13124    PA           2011              250

# %%
df.loc[df['transaction_dt'] == '2013', 'transaction_dt'] = '2014'
df.head()
# Out:
#      cand_id state transaction_dt  transaction_amt
# 0  H4PA13124    PA           2011              250
# 1  H4PA13124    NY           2011              250
# 2  H4PA13124    NY           2011              250
# 3  H4PA13124    PA           2011              250
# 4  H4PA13124    PA           2011              250

# %%
df = df[(df.transaction_dt == "2014")]
df = df[df['transaction_amt']> 0]
df.head()
# Out:
#           cand_id state transaction_dt  transaction_amt
# 991273  H0NY25078    NY           2014             1000
# 991274  H0NY25078    NY           2014             1000
# 991275  H0NY25078    NY           2014             1000
# 991276  H0NY25078    NY           2014             1000
# 991277  H0NY25078    NY           2014             1000

# %%
df.to_csv('donationsclean.csv', sep = ',', index = False)

# %% [markdown]
# ## Format data for map of states showing how much money from out of state is used in their elections.
#
# -   Identify rows of donations where the candidate's state does not match the donor's state. Drop rows where the states match.
# -   Drop the donor state column.
# -   Sum each donation by state of candidate to get sum of out of state money spent in each of those races
# -   Generate choropleth

# %%
df = df.drop("transaction_dt", axis = 1)
df['cand_id'] = df['cand_id'].str[2:4]
df = df[(df.cand_id != df.state)]
df = df.drop("state", axis = 1)

# %%
dfgroup = df.groupby(['cand_id']).transaction_amt.sum()
dfgroup.head()
# Out:
# cand_id
# AK      431484
# AL      847748
# AR    10198594
# AZ     6410950
# CA    16320598
# Name: transaction_amt, dtype: int32

# %%
dfgroup.to_csv("DonationsByDonorState.csv", sep = ',', header = False)

# %%
dfgroup = pd.read_csv("DonationsByDonorState.csv")

# %%
dfgroup.columns = ['state', 'donations']

# %%
dfstates = pd.read_csv('HouseRepState.csv')
dfstates.head()
# Out:
#        ﻿State  Number of House Seats from 2010 State Abbreviation
# 0     Alabama                                7                 AL
# 1      Alaska                                1                 AK
# 2     Arizona                                9                 AZ
# 3    Arkansas                                4                 AR
# 4  California                               53                 CA

# %%
dfstates.columns = ['state name', 'number of seats', 'state']

# %%
df_donor_state = dfgroup.merge(dfstates,on='state')
df_donor_state = df_donor_state.drop("state name", axis = 1)
df_donor_state.columns = ['state', 'donations', 'numberofseats']
df_donor_state = df_donor_state.drop("numberofseats", axis = 1)
df_donor_state.head()
# Out:
#   state  donations
# 0    AL     847748
# 1    AR   10198594
# 2    AZ    6410950
# 3    CA   16320598
# 4    CO    6807148

# %%
df_donor_state.to_csv("OutofStateDonationsSpentInState.csv", sep = ",", index = False)

# %%
dfdonor = pd.read_csv("DonationsByDonorStateFinal.csv")
dfdonor.head()
# Out:
#   state  donations
# 0    AL     847748
# 1    AR   10198594
# 2    AZ    6410950
# 3    CA   16320598
# 4    CO    6807148

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
for col in dfdonor.columns:
    dfdonor[col] = dfdonor[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


dfdonor['text'] = dfdonor['state'] + '<br>' +\
    'Amount Donated '+dfdonor['donations']

    
    
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = dfdonor['state'],
        z = dfdonor['donations'].astype(float),
        locationmode = 'USA-states',
        text = dfdonor['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Dollars Donated")
        ) ]

layout = dict(
        title = 'Amount Spent in 2014 Congressional Elections By Out Of State of Donors' + '<br>' + '(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
iplot(fig)
# Out:
# <div id="80f88fd5-ee04-4da6-82ad-4dddd2f70c26" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("80f88fd5-ee04-4da6-82ad-4dddd2f70c26", [{"marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "locationmode": "USA-states", "z": [847748.0, 10198594.0, 6410950.0, 16320598.0, 6807148.0, 2744586.0, 153582.0, 9350091.0, 4998845.0, 2667033.0, 2152404.0, 873762.0, 8736035.0, 1940626.0, 1626476.0, 2087940.0, 978926.0, 14542581.0, 4033352.0, 865638.0, 11652648.0, 4565933.0, 1132460.0, 655714.0, 4402373.0, 2972533.0, 518525.0, 3387367.0, 3798542.0, 1062525.0, 1291458.0, 12703133.0, 5655210.0, 2206958.0, 2012531.0, 6074959.0, 896976.0, 2075126.0, 347546.0, 1089580.0, 5536610.0, 4191804.0, 8123739.0, 256550.0, 1801082.0, 6095268.0, 2889232.0, 57200.0], "type": "choropleth", "locations": ["AL", "AR", "AZ", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "colorbar": {"title": "Dollars Donated"}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "autocolorscale": false, "text": ["AL<br>Amount Donated 847748", "AR<br>Amount Donated 10198594", "AZ<br>Amount Donated 6410950", "CA<br>Amount Donated 16320598", "CO<br>Amount Donated 6807148", "CT<br>Amount Donated 2744586", "DE<br>Amount Donated 153582", "FL<br>Amount Donated 9350091", "GA<br>Amount Donated 4998845", "HI<br>Amount Donated 2667033", "IA<br>Amount Donated 2152404", "ID<br>Amount Donated 873762", "IL<br>Amount Donated 8736035", "IN<br>Amount Donated 1940626", "KS<br>Amount Donated 1626476", "KY<br>Amount Donated 2087940", "LA<br>Amount Donated 978926", "MA<br>Amount Donated 14542581", "MD<br>Amount Donated 4033352", "ME<br>Amount Donated 865638", "MI<br>Amount Donated 11652648", "MN<br>Amount Donated 4565933", "MO<br>Amount Donated 1132460", "MS<br>Amount Donated 655714", "MT<br>Amount Donated 4402373", "NC<br>Amount Donated 2972533", "ND<br>Amount Donated 518525", "NH<br>Amount Donated 3387367", "NJ<br>Amount Donated 3798542", "NM<br>Amount Donated 1062525", "NV<br>Amount Donated 1291458", "NY<br>Amount Donated 12703133", "OH<br>Amount Donated 5655210", "OK<br>Amount Donated 2206958", "OR<br>Amount Donated 2012531", "PA<br>Amount Donated 6074959", "RI<br>Amount Donated 896976", "SC<br>Amount Donated 2075126", "SD<br>Amount Donated 347546", "TN<br>Amount Donated 1089580", "TX<br>Amount Donated 5536610", "UT<br>Amount Donated 4191804", "VA<br>Amount Donated 8123739", "VT<br>Amount Donated 256550", "WA<br>Amount Donated 1801082", "WI<br>Amount Donated 6095268", "WV<br>Amount Donated 2889232", "WY<br>Amount Donated 57200"]}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "showlakes": true, "projection": {"type": "albers usa"}, "scope": "usa"}, "title": "Amount Spent in 2014 Congressional Elections By Out Of State of Donors<br>(Hover for breakdown)"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## Format data for map of states showing states where donors sent money out of state.
# -   Identify rows of donations where the candidate's state does not match the donor's state. Drop rows where the states match.
# -   Drop the candidate state column.
# -   Sum each donation by state of donor to get sum of donor amount in each state going to other states' races
# -   Generate choropleth

# %%
df = pd.read_csv('donationsclean.csv')

# %%
df = df.drop("transaction_dt", axis = 1)
df['cand_id'] = df['cand_id'].str[2:4]
df = df[(df.cand_id != df.state)]
df = df.drop("cand_id", axis = 1)

# %%
dfgroup = df.groupby(['state']).transaction_amt.sum()
dfgroup.head()
# Out:
# state
# AE       1000
# AK     141573
# AL    1459226
# AP       1000
# AR     798422
# Name: transaction_amt, dtype: int64

# %%
dfgroup.to_csv("OutOfStateDonationsByDonor.csv", sep = ',', header = False)

# %%
dfgroup = pd.read_csv("OutOfStateDonationsByDonor.csv")

# %%
dfgroup.columns = ['state', 'donations']

# %%
dfstates = pd.read_csv('HouseRepState.csv')
dfstates.head()
# Out:
#        ﻿State  Number of House Seats from 2010 State Abbreviation
# 0     Alabama                                7                 AL
# 1      Alaska                                1                 AK
# 2     Arizona                                9                 AZ
# 3    Arkansas                                4                 AR
# 4  California                               53                 CA

# %%
dfstates.columns = ['state name', 'number of seats', 'state']

# %%
df_donor_state = dfgroup.merge(dfstates,on='state')
df_donor_state = df_donor_state.drop("state name", axis = 1)
df_donor_state.columns = ['state', 'donations', 'numberofseats']
df_donor_state = df_donor_state.drop("numberofseats", axis = 1)
df_donor_state.head()
# Out:
#   state  donations
# 0    AK     141573
# 1    AL    1459226
# 2    AR     798422
# 3    AZ    2685695
# 4    CA   24108588

# %%
df_donor_state.to_csv("OutofStateDonationsFromState.csv", sep = ",", index = False)

# %%
dfdonor = pd.read_csv("OutofStateDonationsFromState.csv")
dfdonor.head()
# Out:
#   state  donations
# 0    AK     141573
# 1    AL    1459226
# 2    AR     798422
# 3    AZ    2685695
# 4    CA   24108588

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
for col in dfdonor.columns:
    dfdonor[col] = dfdonor[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


dfdonor['text'] = dfdonor['state'] + '<br>' +\
    'Amount Donated '+dfdonor['donations']

    
    
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = dfdonor['state'],
        z = dfdonor['donations'].astype(float),
        locationmode = 'USA-states',
        text = dfdonor['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Dollars Donated")
        ) ]

layout = dict(
        title = 'Donors who sent Money to Out of State 2014 Congressional Elections' + '<br>' + '(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
iplot(fig)
# Out:
# <div id="4607efbd-fc1e-404c-bfc7-3f89d34023e8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4607efbd-fc1e-404c-bfc7-3f89d34023e8", [{"marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "locationmode": "USA-states", "z": [141573.0, 1459226.0, 798422.0, 2685695.0, 24108588.0, 3005966.0, 4586588.0, 398922.0, 13970142.0, 2507711.0, 284307.0, 458442.0, 337410.0, 8208345.0, 1193993.0, 1301227.0, 824637.0, 1760796.0, 6232447.0, 8896005.0, 545678.0, 2702283.0, 1761294.0, 2630174.0, 585964.0, 187580.0, 1564168.0, 338354.0, 473090.0, 600880.0, 6145785.0, 611737.0, 2038193.0, 22862322.0, 3536372.0, 1796798.0, 686289.0, 4804100.0, 442580.0, 1502364.0, 317414.0, 1562167.0, 13863104.0, 1020160.0, 15962183.0, 423768.0, 2796595.0, 1192043.0, 592984.0, 735232.0], "type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "colorbar": {"title": "Dollars Donated"}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "autocolorscale": false, "text": ["AK<br>Amount Donated 141573", "AL<br>Amount Donated 1459226", "AR<br>Amount Donated 798422", "AZ<br>Amount Donated 2685695", "CA<br>Amount Donated 24108588", "CO<br>Amount Donated 3005966", "CT<br>Amount Donated 4586588", "DE<br>Amount Donated 398922", "FL<br>Amount Donated 13970142", "GA<br>Amount Donated 2507711", "HI<br>Amount Donated 284307", "IA<br>Amount Donated 458442", "ID<br>Amount Donated 337410", "IL<br>Amount Donated 8208345", "IN<br>Amount Donated 1193993", "KS<br>Amount Donated 1301227", "KY<br>Amount Donated 824637", "LA<br>Amount Donated 1760796", "MA<br>Amount Donated 6232447", "MD<br>Amount Donated 8896005", "ME<br>Amount Donated 545678", "MI<br>Amount Donated 2702283", "MN<br>Amount Donated 1761294", "MO<br>Amount Donated 2630174", "MS<br>Amount Donated 585964", "MT<br>Amount Donated 187580", "NC<br>Amount Donated 1564168", "ND<br>Amount Donated 338354", "NE<br>Amount Donated 473090", "NH<br>Amount Donated 600880", "NJ<br>Amount Donated 6145785", "NM<br>Amount Donated 611737", "NV<br>Amount Donated 2038193", "NY<br>Amount Donated 22862322", "OH<br>Amount Donated 3536372", "OK<br>Amount Donated 1796798", "OR<br>Amount Donated 686289", "PA<br>Amount Donated 4804100", "RI<br>Amount Donated 442580", "SC<br>Amount Donated 1502364", "SD<br>Amount Donated 317414", "TN<br>Amount Donated 1562167", "TX<br>Amount Donated 13863104", "UT<br>Amount Donated 1020160", "VA<br>Amount Donated 15962183", "VT<br>Amount Donated 423768", "WA<br>Amount Donated 2796595", "WI<br>Amount Donated 1192043", "WV<br>Amount Donated 592984", "WY<br>Amount Donated 735232"]}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "showlakes": true, "projection": {"type": "albers usa"}, "scope": "usa"}, "title": "Donors who sent Money to Out of State 2014 Congressional Elections<br>(Hover for breakdown)"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## Format data for map average amount of money spent for each race, in each state
#
# -   Label the cand_id with the state they are running for election in
# -   Group all states together to get the amount spent (by individual donors) in each state
# -   Normalize amount of donations for the number of races in each state

# %%
df = pd.read_csv("donationsclean.csv")
df.head()
# Out:
#      cand_id state  transaction_dt  transaction_amt
# 0  H0NY25078    NY            2014             1000
# 1  H0NY25078    NY            2014             1000
# 2  H0NY25078    NY            2014             1000
# 3  H0NY25078    NY            2014             1000
# 4  H0NY25078    NY            2014             1000

# %%
df['cand_id'] = df['cand_id'].str[2:4]
df.head()
# Out:
#   cand_id state  transaction_dt  transaction_amt
# 0      NY    NY            2014             1000
# 1      NY    NY            2014             1000
# 2      NY    NY            2014             1000
# 3      NY    NY            2014             1000
# 4      NY    NY            2014             1000

# %%
df = df.drop("state", axis = 1)

# %%
df.to_csv("DonationsByRaceState.csv", sep = ',', index = False)

# %%
df.head()
# Out:
#   cand_id  transaction_dt  transaction_amt
# 0      NY            2014             1000
# 1      NY            2014             1000
# 2      NY            2014             1000
# 3      NY            2014             1000
# 4      NY            2014             1000

# %%
df = df.drop("transaction_dt", axis = 1)

# %%
dfgroup = df.groupby(['cand_id']).transaction_amt.sum()
dfgroup.head()
# Out:
# cand_id
# AK      733248
# AL     4935335
# AR    17697844
# AZ    20393553
# CA    77747745
# Name: transaction_amt, dtype: int64

# %%
dfgroup.to_csv("DonationsByRaceState.csv", sep = ',', header = False)

# %%
dfgroup = pd.read_csv("DonationsByRaceState.csv", header = None)
dfgroup.head()
# Out:
#     0         1
# 0  AK    733248
# 1  AL   4935335
# 2  AR  17697844
# 3  AZ  20393553
# 4  CA  77747745

# %%
dfgroup.columns = ['state', 'donations']

# %%
dfstates = pd.read_csv('HouseRepState.csv')

# %%
dfstates.columns = ['state name', 'numberofseats', 'state']

# %%
df_race_state = dfgroup.merge(dfstates,on='state')
df_race_state.head()
# Out:
#   state  donations  state name  numberofseats
# 0    AK     733248      Alaska              1
# 1    AL    4935335     Alabama              7
# 2    AR   17697844    Arkansas              4
# 3    AZ   20393553     Arizona              9
# 4    CA   77747745  California             53

# %%
df_race_state['normalized'] = df_race_state['donations']/df_race_state['numberofseats']

# %%
df_race_state.head()
# Out:
#   state  donations  state name  numberofseats    normalized
# 0    AK     733248      Alaska              1  7.332480e+05
# 1    AL    4935335     Alabama              7  7.050479e+05
# 2    AR   17697844    Arkansas              4  4.424461e+06
# 3    AZ   20393553     Arizona              9  2.265950e+06
# 4    CA   77747745  California             53  1.466939e+06

# %%
df_race_state = df_race_state.drop("numberofseats", axis = 1)
df_race_state = df_race_state.drop("state name", axis = 1)
df_race_state = df_race_state.drop("donations", axis = 1)

# %%
df_race_state.to_csv("DonationsByRaceStateFinal.csv", sep = ',', index = False)

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df_state = pd.read_csv("DonationsByRaceStateFinal.csv")
df_state.head()
# Out:
#   state    normalized
# 0    AK  7.332480e+05
# 1    AL  7.050479e+05
# 2    AR  4.424461e+06
# 3    AZ  2.265950e+06
# 4    CA  1.466939e+06

# %%
for col in df_state.columns:
    df_state[col] = df_state[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


df_state['text'] = df_state['state'] + '<br>' +\
    'Amount Donated '+df_state['normalized']

    
    
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df_state['state'],
        z = df_state['normalized'].astype(float),
        locationmode = 'USA-states',
        text = df_state['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Dollars Donated")
        ) ]

layout = dict(
        title = 'Average Amount Spent In Each State in 2014 Congressional Representatives Elections' + '<br>' + '(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
iplot(fig)
# Out:
# <div id="a2e9dfe7-01c8-4849-95cb-5e0dfe71d210" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a2e9dfe7-01c8-4849-95cb-5e0dfe71d210", [{"marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "locationmode": "USA-states", "z": [733248.0, 705047.857143, 4424461.0, 2265950.33333, 1466938.58491, 3143239.28571, 1761572.0, 419112.0, 1388467.7037, 1343937.14286, 3236423.0, 1721639.5, 958433.5, 2112357.05556, 1067279.33333, 1686621.5, 985104.666667, 1352705.33333, 3473327.77778, 964092.0, 1230813.0, 2271726.07143, 1709369.625, 832021.375, 679113.5, 7689752.0, 887626.538462, 2124799.0, 3345207.0, 1021535.25, 1757454.66667, 1438163.75, 1838739.74074, 1301216.3125, 2001204.2, 980184.2, 1173440.16667, 1118591.0, 874980.857143, 2353473.0, 947699.222222, 1024054.13889, 1593212.75, 1880697.36364, 523144.0, 966294.1, 1324941.25, 2067218.33333, 146350.0], "type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "colorbar": {"title": "Dollars Donated"}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "autocolorscale": false, "text": ["AK<br>Amount Donated 733248.0", "AL<br>Amount Donated 705047.857143", "AR<br>Amount Donated 4424461.0", "AZ<br>Amount Donated 2265950.33333", "CA<br>Amount Donated 1466938.58491", "CO<br>Amount Donated 3143239.28571", "CT<br>Amount Donated 1761572.0", "DE<br>Amount Donated 419112.0", "FL<br>Amount Donated 1388467.7037", "GA<br>Amount Donated 1343937.14286", "HI<br>Amount Donated 3236423.0", "IA<br>Amount Donated 1721639.5", "ID<br>Amount Donated 958433.5", "IL<br>Amount Donated 2112357.05556", "IN<br>Amount Donated 1067279.33333", "KS<br>Amount Donated 1686621.5", "KY<br>Amount Donated 985104.666667", "LA<br>Amount Donated 1352705.33333", "MA<br>Amount Donated 3473327.77778", "MD<br>Amount Donated 964092.0", "ME<br>Amount Donated 1230813.0", "MI<br>Amount Donated 2271726.07143", "MN<br>Amount Donated 1709369.625", "MO<br>Amount Donated 832021.375", "MS<br>Amount Donated 679113.5", "MT<br>Amount Donated 7689752.0", "NC<br>Amount Donated 887626.538462", "ND<br>Amount Donated 2124799.0", "NH<br>Amount Donated 3345207.0", "NJ<br>Amount Donated 1021535.25", "NM<br>Amount Donated 1757454.66667", "NV<br>Amount Donated 1438163.75", "NY<br>Amount Donated 1838739.74074", "OH<br>Amount Donated 1301216.3125", "OK<br>Amount Donated 2001204.2", "OR<br>Amount Donated 980184.2", "PA<br>Amount Donated 1173440.16667", "RI<br>Amount Donated 1118591.0", "SC<br>Amount Donated 874980.857143", "SD<br>Amount Donated 2353473.0", "TN<br>Amount Donated 947699.222222", "TX<br>Amount Donated 1024054.13889", "UT<br>Amount Donated 1593212.75", "VA<br>Amount Donated 1880697.36364", "VT<br>Amount Donated 523144.0", "WA<br>Amount Donated 966294.1", "WI<br>Amount Donated 1324941.25", "WV<br>Amount Donated 2067218.33333", "WY<br>Amount Donated 146350.0"]}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "showlakes": true, "projection": {"type": "albers usa"}, "scope": "usa"}, "title": "Average Amount Spent In Each State in 2014 Congressional Representatives Elections<br>(Hover for breakdown)"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## Generating the Chloropleths
#
#
#
# Code is adapted from here: https://plot.ly/pandas/choropleth-maps/
